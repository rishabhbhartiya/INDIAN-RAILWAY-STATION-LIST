# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('/content/INDIAN RAILWAY STATION.csv')

# %%
pd.set_option('display.max_rows', None)
dataset

# %%
dataset.dropna(thresh=len(dataset.columns)-1, inplace=True)

# %%
dataset.shape #8938 total station should be
# Out:
# (9296, 5)

# %%
dataset.head(6)
# Out:
#    Unnamed: 0     0                    1             2  \
# 1           1  Code         Station Name  Railway Zone
# 2           2    AA               ATARIA           NER
# 3           3  AABH  AMBIKA BHAWANI HALT           ECR
# 4           4  AADR           AMBANDAURA            NR
# 5           5   AAG                ANGAR            CR
# 6           6  AAGH             ANTAGARH          SECR
#
#                                           3
# 1                           Station Address
# 2  Sitapur Rd, Heerpur, Uttar Pradesh 261..
# 3  Chapra-Patna Highway, Rampur Ami, Biha..
# 4              Una, Himachal Pradesh, India
# 5               Solapur, Maharashtra, India
# 6  Antagarh, PIN - 494665, Dist. - Kanker..

# %%
dataset = dataset[dataset['0'] != 'Code']

# %%
dataset.shape
# Out:
# (8938, 5)

# %%
dataset.head(6)
# Out:
#    Unnamed: 0     0                    1     2  \
# 2           2    AA               ATARIA   NER
# 3           3  AABH  AMBIKA BHAWANI HALT   ECR
# 4           4  AADR           AMBANDAURA    NR
# 5           5   AAG                ANGAR    CR
# 6           6  AAGH             ANTAGARH  SECR
# 7           7   AAH               ITEHAR   NCR
#
#                                           3
# 2  Sitapur Rd, Heerpur, Uttar Pradesh 261..
# 3  Chapra-Patna Highway, Rampur Ami, Biha..
# 4              Una, Himachal Pradesh, India
# 5               Solapur, Maharashtra, India
# 6  Antagarh, PIN - 494665, Dist. - Kanker..
# 7                Itahar, West Bengal, India

# %%
dataset.rename(columns={'0': 'CODE', '1': 'STATION NAME', '2': 'RAILWAY ZONE', '3': 'STATION ADDRESS'}, inplace=True)
# Out:
# <ipython-input-24-d9ce1156698e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.rename(columns={'0': 'CODE', '1': 'STATION NAME', '2': 'RAILWAY ZONE', '3': 'STATION ADDRESS'}, inplace=True)

# %%
dataset.head(6)
# Out:
#    Unnamed: 0  CODE         STATION NAME RAILWAY ZONE  \
# 2           2    AA               ATARIA          NER
# 3           3  AABH  AMBIKA BHAWANI HALT          ECR
# 4           4  AADR           AMBANDAURA           NR
# 5           5   AAG                ANGAR           CR
# 6           6  AAGH             ANTAGARH         SECR
# 7           7   AAH               ITEHAR          NCR
#
#                             STATION ADDRESS
# 2  Sitapur Rd, Heerpur, Uttar Pradesh 261..
# 3  Chapra-Patna Highway, Rampur Ami, Biha..
# 4              Una, Himachal Pradesh, India
# 5               Solapur, Maharashtra, India
# 6  Antagarh, PIN - 494665, Dist. - Kanker..
# 7                Itahar, West Bengal, India

# %%
dataset = dataset.drop('Unnamed: 0', axis=1)

# %%
dataset = dataset.reset_index(drop=True)

# %%
dataset.head(5 )
# Out:
#    CODE         STATION NAME RAILWAY ZONE  \
# 0    AA               ATARIA          NER
# 1  AABH  AMBIKA BHAWANI HALT          ECR
# 2  AADR           AMBANDAURA           NR
# 3   AAG                ANGAR           CR
# 4  AAGH             ANTAGARH         SECR
#
#                             STATION ADDRESS
# 0  Sitapur Rd, Heerpur, Uttar Pradesh 261..
# 1  Chapra-Patna Highway, Rampur Ami, Biha..
# 2              Una, Himachal Pradesh, India
# 3               Solapur, Maharashtra, India
# 4  Antagarh, PIN - 494665, Dist. - Kanker..

# %%
dataset.to_csv("INDIAN RAILWAY STATION LIST.csv")
